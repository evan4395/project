# %%
import torch
from torch.utils.data import Dataset
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torchvision.models as models
import matplotlib.pyplot as plt

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'torch version : {torch.__version__}')
print(f'device : {device}')
# Out:
# torch version : 2.7.1+cpu
# device : cpu

# %%
# Download data : MNIST

training_data = datasets.FashionMNIST(
    root='../data',
    train=True,
    download=False,
    transform=transforms.ToTensor()
)

test_data = datasets.FashionMNIST(
    root='../data',
    train=False,
    download=False,
    transform=transforms.ToTensor()
)

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

# %%
figure = plt.figure(figsize=(8,8))
cols, rows = 3, 3
for i in range(1, cols*rows +1):
    sample_idx =  torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis('off')
    plt.imshow(img.squeeze(), cmap='gray')
plt.show()

# %%
train_dataloader = DataLoader(training_data, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.sequential = nn.Sequential(nn.Linear(28*28, 512),
                                      nn.ReLU(),
                                      nn.Linear(512, 256),
                                      nn.ReLU(),
                                      nn.Linear(256, 10)
                                     )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.sequential(x)
        return logits

# %%
model = MLP().to(device)
print(model)
# Out:
# MLP(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (sequential): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
learning_rate = 1e-3
batch_size = 64
epochs = 50

# %%
loss_fn = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        pred = model(X)
        loss = loss_fn(pred, y)

        # 역전파
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * batch_size + len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    return loss
            
def test_loop(dataloader, model, loss_fn):
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f'Test Error: \n Accuracy: {(100*correct):0.1f}%, Avg loss: {test_loss:>8f} \n')

# %%
res = []
for t in range(epochs):
    print(f'Epoch {t+1}\n------------------------------')
    loss = train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
    res.append([t, loss])
print('Done!')
# Out:
# Epoch 1
# ------------------------------
# loss: 2.306836  [   64/60000]
# loss: 2.288058  [ 6464/60000]
# loss: 2.270111  [12864/60000]
# loss: 2.259811  [19264/60000]
# loss: 2.241662  [25664/60000]
# loss: 2.238734  [32064/60000]
# loss: 2.233062  [38464/60000]
# loss: 2.193986  [44864/60000]
# loss: 2.185211  [51264/60000]
# loss: 2.170267  [57664/60000]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 2.161107
#
# Epoch 2
# ------------------------------
# loss: 2.144437  [   64/60000]
# loss: 2.141294  [ 6464/60000]
# loss: 2.128024  [12864/60000]
# loss: 2.107304  [19264/60000]
# loss: 2.072066  [25664/60000]
# loss: 2.020514  [32064/60000]
# loss: 2.024482  [38464/60000]
# loss: 1.968740  [44864/60000]
# loss: 1.954954  [51264/60000]
# loss: 1.932206  [57664/60000]
# Test Error:
#  Accuracy: 53.7%, Avg loss: 1.898703
#
# Epoch 3
# ------------------------------
# loss: 1.954075  [   64/60000]
# loss: 1.886864  [ 6464/60000]
# loss: 1.795458  [12864/60000]
# loss: 1.786430  [19264/60000]
# loss: 1.804452  [25664/60000]
# loss: 1.700293  [32064/60000]
# loss: 1.698496  [38464/60000]
# loss: 1.632549  [44864/60000]
# loss: 1.608700  [51264/60000]
# loss: 1.654225  [57664/60000]
# Test Error:
#  Accuracy: 58.9%, Avg loss: 1.555113
#
# Epoch 4
# ------------------------------
# loss: 1.556825  [   64/60000]
# loss: 1.551678  [ 6464/60000]
# loss: 1.482884  [12864/60000]
# loss: 1.456068  [19264/60000]
# loss: 1.437540  [25664/60000]
# loss: 1.448698  [32064/60000]
# loss: 1.318469  [38464/60000]
# loss: 1.272075  [44864/60000]
# loss: 1.361415  [51264/60000]
# loss: 1.425253  [57664/60000]
# Test Error:
#  Accuracy: 62.1%, Avg loss: 1.300613
#
# Epoch 5
# ------------------------------
# loss: 1.171108  [   64/60000]
# loss: 1.385636  [ 6464/60000]
# loss: 1.206591  [12864/60000]
# loss: 1.177224  [19264/60000]
# loss: 1.154350  [25664/60000]
# loss: 1.221337  [32064/60000]
# loss: 1.133517  [38464/60000]
# loss: 1.132089  [44864/60000]
# loss: 1.135311  [51264/60000]
# loss: 1.050191  [57664/60000]
# Test Error:
#  Accuracy: 64.6%, Avg loss: 1.132803
#
# Epoch 6
# ------------------------------
# loss: 1.166775  [   64/60000]
# loss: 1.235795  [ 6464/60000]
# loss: 1.080028  [12864/60000]
# loss: 0.971559  [19264/60000]
# loss: 1.098714  [25664/60000]
# loss: 1.027659  [32064/60000]
# loss: 0.996495  [38464/60000]
# loss: 1.006833  [44864/60000]
# loss: 0.989885  [51264/60000]
# loss: 0.958786  [57664/60000]
# Test Error:
#  Accuracy: 65.8%, Avg loss: 1.018298
#
# Epoch 7
# ------------------------------
# loss: 0.926546  [   64/60000]
# loss: 0.960915  [ 6464/60000]
# loss: 0.986712  [12864/60000]
# loss: 0.958442  [19264/60000]
# loss: 1.107145  [25664/60000]
# loss: 0.892023  [32064/60000]
# loss: 0.907993  [38464/60000]
# loss: 0.983894  [44864/60000]
# loss: 1.291710  [51264/60000]
# loss: 0.923452  [57664/60000]
# Test Error:
#  Accuracy: 67.0%, Avg loss: 0.938738
#
# Epoch 8
# ------------------------------
# loss: 0.963728  [   64/60000]
# loss: 0.911047  [ 6464/60000]
# loss: 0.880574  [12864/60000]
# loss: 0.791803  [19264/60000]
# loss: 1.081059  [25664/60000]
# loss: 1.003815  [32064/60000]
# loss: 0.776166  [38464/60000]
# loss: 0.826808  [44864/60000]
# loss: 0.949059  [51264/60000]
# loss: 0.709444  [57664/60000]
# Test Error:
#  Accuracy: 68.0%, Avg loss: 0.882434
#
# Epoch 9
# ------------------------------
# loss: 0.761738  [   64/60000]
# loss: 0.819971  [ 6464/60000]
# loss: 0.772055  [12864/60000]
# loss: 0.871049  [19264/60000]
# loss: 0.760139  [25664/60000]
# loss: 0.735718  [32064/60000]
# loss: 0.779203  [38464/60000]
# loss: 0.773115  [44864/60000]
# loss: 0.838375  [51264/60000]
# loss: 0.761179  [57664/60000]
# Test Error:
#  Accuracy: 69.1%, Avg loss: 0.840276
#
# Epoch 10
# ------------------------------
# loss: 0.898887  [   64/60000]
# loss: 0.699783  [ 6464/60000]
# loss: 0.673725  [12864/60000]
# loss: 0.802067  [19264/60000]
# loss: 0.789251  [25664/60000]
# loss: 0.596169  [32064/60000]
# loss: 0.713271  [38464/60000]
# loss: 0.796837  [44864/60000]
# loss: 0.751315  [51264/60000]
# loss: 0.701375  [57664/60000]
# Test Error:
#  Accuracy: 70.2%, Avg loss: 0.806719
#
# Epoch 11
# ------------------------------
# loss: 0.971488  [   64/60000]
# loss: 1.049062  [ 6464/60000]
# loss: 0.764144  [12864/60000]
# loss: 0.846312  [19264/60000]
# loss: 0.707673  [25664/60000]
# loss: 0.873019  [32064/60000]
# loss: 0.642199  [38464/60000]
# loss: 0.830936  [44864/60000]
# loss: 0.935472  [51264/60000]
# loss: 0.743804  [57664/60000]
# Test Error:
#  Accuracy: 71.6%, Avg loss: 0.779650
#
# Epoch 12
# ------------------------------
# loss: 0.657580  [   64/60000]
# loss: 0.822540  [ 6464/60000]
# loss: 0.910675  [12864/60000]
# loss: 0.643661  [19264/60000]
# loss: 0.645717  [25664/60000]
# loss: 0.641065  [32064/60000]
# loss: 0.670152  [38464/60000]
# loss: 0.747678  [44864/60000]
# loss: 0.924311  [51264/60000]
# loss: 0.710271  [57664/60000]
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.756217
#
# Epoch 13
# ------------------------------
# loss: 0.841051  [   64/60000]
# loss: 0.826528  [ 6464/60000]
# loss: 0.778968  [12864/60000]
# loss: 0.764979  [19264/60000]
# loss: 0.678059  [25664/60000]
# loss: 0.706695  [32064/60000]
# loss: 0.672102  [38464/60000]
# loss: 0.715752  [44864/60000]
# loss: 0.617221  [51264/60000]
# loss: 0.814107  [57664/60000]
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.736204
#
# Epoch 14
# ------------------------------
# loss: 0.757718  [   64/60000]
# loss: 0.785802  [ 6464/60000]
# loss: 0.643085  [12864/60000]
# loss: 0.710275  [19264/60000]
# loss: 0.708301  [25664/60000]
# loss: 0.722249  [32064/60000]
# loss: 0.774989  [38464/60000]
# loss: 0.670904  [44864/60000]
# loss: 0.757913  [51264/60000]
# loss: 0.639321  [57664/60000]
# Test Error:
#  Accuracy: 74.2%, Avg loss: 0.716187
#
# Epoch 15
# ------------------------------
# loss: 0.792928  [   64/60000]
# loss: 0.685208  [ 6464/60000]
# loss: 0.679170  [12864/60000]
# loss: 0.712123  [19264/60000]
# loss: 0.649944  [25664/60000]
# loss: 0.831432  [32064/60000]
# loss: 0.777256  [38464/60000]
# loss: 0.583894  [44864/60000]
# loss: 0.716379  [51264/60000]
# loss: 0.735372  [57664/60000]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.701394
#
# Epoch 16
# ------------------------------
# loss: 0.534912  [   64/60000]
# loss: 0.693047  [ 6464/60000]
# loss: 0.640459  [12864/60000]
# loss: 0.605868  [19264/60000]
# loss: 0.727779  [25664/60000]
# loss: 0.687039  [32064/60000]
# loss: 0.660847  [38464/60000]
# loss: 0.694052  [44864/60000]
# loss: 0.479608  [51264/60000]
# loss: 0.575562  [57664/60000]
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.686095
#
# Epoch 17
# ------------------------------
# loss: 0.768155  [   64/60000]
# loss: 0.617342  [ 6464/60000]
# loss: 0.570346  [12864/60000]
# loss: 0.747055  [19264/60000]
# loss: 0.669275  [25664/60000]
# loss: 0.825406  [32064/60000]
# loss: 0.620567  [38464/60000]
# loss: 0.501707  [44864/60000]
# loss: 0.618722  [51264/60000]
# loss: 0.678211  [57664/60000]
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.674048
#
# Epoch 18
# ------------------------------
# loss: 0.635767  [   64/60000]
# loss: 0.689030  [ 6464/60000]
# loss: 0.526023  [12864/60000]
# loss: 0.844849  [19264/60000]
# loss: 0.665586  [25664/60000]
# loss: 0.714480  [32064/60000]
# loss: 0.717353  [38464/60000]
# loss: 0.669173  [44864/60000]
# loss: 0.574027  [51264/60000]
# loss: 0.577684  [57664/60000]
# Test Error:
#  Accuracy: 76.8%, Avg loss: 0.658527
#
# Epoch 19
# ------------------------------
# loss: 0.602814  [   64/60000]
# loss: 0.707040  [ 6464/60000]
# loss: 0.621256  [12864/60000]
# loss: 0.621583  [19264/60000]
# loss: 0.486607  [25664/60000]
# loss: 0.734636  [32064/60000]
# loss: 0.606985  [38464/60000]
# loss: 0.757605  [44864/60000]
# loss: 0.666435  [51264/60000]
# loss: 0.600196  [57664/60000]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.648304
#
# Epoch 20
# ------------------------------
# loss: 0.595364  [   64/60000]
# loss: 0.691739  [ 6464/60000]
# loss: 0.592220  [12864/60000]
# loss: 0.554607  [19264/60000]
# loss: 0.581332  [25664/60000]
# loss: 0.487013  [32064/60000]
# loss: 0.557937  [38464/60000]
# loss: 0.549351  [44864/60000]
# loss: 0.854657  [51264/60000]
# loss: 0.526622  [57664/60000]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.636672
#
# Epoch 21
# ------------------------------
# loss: 0.646385  [   64/60000]
# loss: 0.731926  [ 6464/60000]
# loss: 0.496581  [12864/60000]
# loss: 0.426650  [19264/60000]
# loss: 0.563951  [25664/60000]
# loss: 0.506458  [32064/60000]
# loss: 0.579767  [38464/60000]
# loss: 0.560048  [44864/60000]
# loss: 0.574041  [51264/60000]
# loss: 0.586374  [57664/60000]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.624746
#
# Epoch 22
# ------------------------------
# loss: 0.704468  [   64/60000]
# loss: 0.615114  [ 6464/60000]
# loss: 0.574033  [12864/60000]
# loss: 0.619582  [19264/60000]
# loss: 0.821050  [25664/60000]
# loss: 0.718966  [32064/60000]
# loss: 0.567585  [38464/60000]
# loss: 0.838950  [44864/60000]
# loss: 0.598877  [51264/60000]
# loss: 0.626894  [57664/60000]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.614648
#
# Epoch 23
# ------------------------------
# loss: 0.558635  [   64/60000]
# loss: 0.656767  [ 6464/60000]
# loss: 0.625153  [12864/60000]
# loss: 0.441372  [19264/60000]
# loss: 0.607478  [25664/60000]
# loss: 0.685609  [32064/60000]
# loss: 0.578570  [38464/60000]
# loss: 0.617133  [44864/60000]
# loss: 0.576367  [51264/60000]
# loss: 0.437501  [57664/60000]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.606655
#
# Epoch 24
# ------------------------------
# loss: 0.531100  [   64/60000]
# loss: 0.673281  [ 6464/60000]
# loss: 0.514145  [12864/60000]
# loss: 0.532049  [19264/60000]
# loss: 0.358366  [25664/60000]
# loss: 0.586740  [32064/60000]
# loss: 0.643492  [38464/60000]
# loss: 0.423749  [44864/60000]
# loss: 0.642309  [51264/60000]
# loss: 0.556652  [57664/60000]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.598420
#
# Epoch 25
# ------------------------------
# loss: 0.606987  [   64/60000]
# loss: 0.642960  [ 6464/60000]
# loss: 0.498284  [12864/60000]
# loss: 0.606001  [19264/60000]
# loss: 0.464825  [25664/60000]
# loss: 0.576841  [32064/60000]
# loss: 0.642961  [38464/60000]
# loss: 0.737854  [44864/60000]
# loss: 0.435833  [51264/60000]
# loss: 0.553105  [57664/60000]
# Test Error:
#  Accuracy: 79.5%, Avg loss: 0.591796
#
# Epoch 26
# ------------------------------
# loss: 0.557226  [   64/60000]
# loss: 0.415678  [ 6464/60000]
# loss: 0.514912  [12864/60000]
# loss: 0.435825  [19264/60000]
# loss: 0.653988  [25664/60000]
# loss: 0.627268  [32064/60000]
# loss: 0.662247  [38464/60000]
# loss: 0.576928  [44864/60000]
# loss: 0.399588  [51264/60000]
# loss: 0.478610  [57664/60000]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.586760
#
# Epoch 27
# ------------------------------
# loss: 0.601349  [   64/60000]
# loss: 0.407182  [ 6464/60000]
# loss: 0.445391  [12864/60000]
# loss: 0.566284  [19264/60000]
# loss: 0.506299  [25664/60000]
# loss: 0.698148  [32064/60000]
# loss: 0.701750  [38464/60000]
# loss: 0.624541  [44864/60000]
# loss: 0.464232  [51264/60000]
# loss: 0.524981  [57664/60000]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.576019
#
# Epoch 28
# ------------------------------
# loss: 0.716198  [   64/60000]
# loss: 0.499290  [ 6464/60000]
# loss: 0.437338  [12864/60000]
# loss: 0.577278  [19264/60000]
# loss: 0.618853  [25664/60000]
# loss: 0.563834  [32064/60000]
# loss: 0.483906  [38464/60000]
# loss: 0.544448  [44864/60000]
# loss: 0.562977  [51264/60000]
# loss: 0.412035  [57664/60000]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.570775
#
# Epoch 29
# ------------------------------
# loss: 0.476830  [   64/60000]
# loss: 0.551975  [ 6464/60000]
# loss: 0.613550  [12864/60000]
# loss: 0.587416  [19264/60000]
# loss: 0.519500  [25664/60000]
# loss: 0.773317  [32064/60000]
# loss: 0.445404  [38464/60000]
# loss: 0.574918  [44864/60000]
# loss: 0.545521  [51264/60000]
# loss: 0.518629  [57664/60000]
# Test Error:
#  Accuracy: 80.2%, Avg loss: 0.563682
#
# Epoch 30
# ------------------------------
# loss: 0.648739  [   64/60000]
# loss: 0.546173  [ 6464/60000]
# loss: 0.433860  [12864/60000]
# loss: 0.542836  [19264/60000]
# loss: 0.627495  [25664/60000]
# loss: 0.424231  [32064/60000]
# loss: 0.396764  [38464/60000]
# loss: 0.449887  [44864/60000]
# loss: 0.651640  [51264/60000]
# loss: 0.316070  [57664/60000]
# Test Error:
#  Accuracy: 80.5%, Avg loss: 0.558902
#
# Epoch 31
# ------------------------------
# loss: 0.390422  [   64/60000]
# loss: 0.610943  [ 6464/60000]
# loss: 0.555416  [12864/60000]
# loss: 0.479221  [19264/60000]
# loss: 0.587416  [25664/60000]
# loss: 0.305349  [32064/60000]
# loss: 0.531143  [38464/60000]
# loss: 0.645380  [44864/60000]
# loss: 0.392148  [51264/60000]
# loss: 0.547870  [57664/60000]
# Test Error:
#  Accuracy: 80.7%, Avg loss: 0.552250
#
# Epoch 32
# ------------------------------
# loss: 0.449671  [   64/60000]
# loss: 0.517664  [ 6464/60000]
# loss: 0.652612  [12864/60000]
# loss: 0.550990  [19264/60000]
# loss: 0.605598  [25664/60000]
# loss: 0.459282  [32064/60000]
# loss: 0.556912  [38464/60000]
# loss: 0.629085  [44864/60000]
# loss: 0.337661  [51264/60000]
# loss: 0.632126  [57664/60000]
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.546582
#
# Epoch 33
# ------------------------------
# loss: 0.556837  [   64/60000]
# loss: 0.399468  [ 6464/60000]
# loss: 0.423227  [12864/60000]
# loss: 0.840884  [19264/60000]
# loss: 0.546477  [25664/60000]
# loss: 0.427458  [32064/60000]
# loss: 0.572570  [38464/60000]
# loss: 0.612180  [44864/60000]
# loss: 0.605178  [51264/60000]
# loss: 0.613141  [57664/60000]
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.542823
#
# Epoch 34
# ------------------------------
# loss: 0.512477  [   64/60000]
# loss: 0.565786  [ 6464/60000]
# loss: 0.594688  [12864/60000]
# loss: 0.464577  [19264/60000]
# loss: 0.393817  [25664/60000]
# loss: 0.482317  [32064/60000]
# loss: 0.678830  [38464/60000]
# loss: 0.576784  [44864/60000]
# loss: 0.436746  [51264/60000]
# loss: 0.450610  [57664/60000]
# Test Error:
#  Accuracy: 81.1%, Avg loss: 0.540162
#
# Epoch 35
# ------------------------------
# loss: 0.532390  [   64/60000]
# loss: 0.478872  [ 6464/60000]
# loss: 0.594048  [12864/60000]
# loss: 0.325507  [19264/60000]
# loss: 0.540173  [25664/60000]
# loss: 0.710679  [32064/60000]
# loss: 0.472764  [38464/60000]
# loss: 0.536173  [44864/60000]
# loss: 0.631364  [51264/60000]
# loss: 0.495812  [57664/60000]
# Test Error:
#  Accuracy: 81.4%, Avg loss: 0.535535
#
# Epoch 36
# ------------------------------
# loss: 0.501200  [   64/60000]
# loss: 0.392648  [ 6464/60000]
# loss: 0.724231  [12864/60000]
# loss: 0.470481  [19264/60000]
# loss: 0.509528  [25664/60000]
# loss: 0.582266  [32064/60000]
# loss: 0.590406  [38464/60000]
# loss: 0.471820  [44864/60000]
# loss: 0.485297  [51264/60000]
# loss: 0.462491  [57664/60000]
# Test Error:
#  Accuracy: 81.4%, Avg loss: 0.533014
#
# Epoch 37
# ------------------------------
# loss: 0.511379  [   64/60000]
# loss: 0.718225  [ 6464/60000]
# loss: 0.399829  [12864/60000]
# loss: 0.523388  [19264/60000]
# loss: 0.465899  [25664/60000]
# loss: 0.599799  [32064/60000]
# loss: 0.444209  [38464/60000]
# loss: 0.412697  [44864/60000]
# loss: 0.491900  [51264/60000]
# loss: 0.540018  [57664/60000]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.528076
#
# Epoch 38
# ------------------------------
# loss: 0.485210  [   64/60000]
# loss: 0.515436  [ 6464/60000]
# loss: 0.587068  [12864/60000]
# loss: 0.438983  [19264/60000]
# loss: 0.558991  [25664/60000]
# loss: 0.359759  [32064/60000]
# loss: 0.353218  [38464/60000]
# loss: 0.476213  [44864/60000]
# loss: 0.430360  [51264/60000]
# loss: 0.572282  [57664/60000]
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.525666
#
# Epoch 39
# ------------------------------
# loss: 0.362201  [   64/60000]
# loss: 0.460557  [ 6464/60000]
# loss: 0.329215  [12864/60000]
# loss: 0.450825  [19264/60000]
# loss: 0.461310  [25664/60000]
# loss: 0.595290  [32064/60000]
# loss: 0.489670  [38464/60000]
# loss: 0.555403  [44864/60000]
# loss: 0.396476  [51264/60000]
# loss: 0.540497  [57664/60000]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.521181
#
# Epoch 40
# ------------------------------
# loss: 0.321009  [   64/60000]
# loss: 0.438196  [ 6464/60000]
# loss: 0.527477  [12864/60000]
# loss: 0.482154  [19264/60000]
# loss: 0.354554  [25664/60000]
# loss: 0.335374  [32064/60000]
# loss: 0.527042  [38464/60000]
# loss: 0.522834  [44864/60000]
# loss: 0.431656  [51264/60000]
# loss: 0.555061  [57664/60000]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.519849
#
# Epoch 41
# ------------------------------
# loss: 0.532929  [   64/60000]
# loss: 0.411497  [ 6464/60000]
# loss: 0.424586  [12864/60000]
# loss: 0.768142  [19264/60000]
# loss: 0.560219  [25664/60000]
# loss: 0.439035  [32064/60000]
# loss: 0.389915  [38464/60000]
# loss: 0.556892  [44864/60000]
# loss: 0.490096  [51264/60000]
# loss: 0.435566  [57664/60000]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.515590
#
# Epoch 42
# ------------------------------
# loss: 0.583810  [   64/60000]
# loss: 0.405988  [ 6464/60000]
# loss: 0.427438  [12864/60000]
# loss: 0.337795  [19264/60000]
# loss: 0.486541  [25664/60000]
# loss: 0.585245  [32064/60000]
# loss: 0.515354  [38464/60000]
# loss: 0.580796  [44864/60000]
# loss: 0.559203  [51264/60000]
# loss: 0.487475  [57664/60000]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.511080
#
# Epoch 43
# ------------------------------
# loss: 0.563688  [   64/60000]
# loss: 0.387829  [ 6464/60000]
# loss: 0.616875  [12864/60000]
# loss: 0.499660  [19264/60000]
# loss: 0.613406  [25664/60000]
# loss: 0.553788  [32064/60000]
# loss: 0.453967  [38464/60000]
# loss: 0.666292  [44864/60000]
# loss: 0.486827  [51264/60000]
# loss: 0.726665  [57664/60000]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.509427
#
# Epoch 44
# ------------------------------
# loss: 0.334697  [   64/60000]
# loss: 0.518327  [ 6464/60000]
# loss: 0.419582  [12864/60000]
# loss: 0.424239  [19264/60000]
# loss: 0.388922  [25664/60000]
# loss: 0.506445  [32064/60000]
# loss: 0.328466  [38464/60000]
# loss: 0.398282  [44864/60000]
# loss: 0.548240  [51264/60000]
# loss: 0.552676  [57664/60000]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.509615
#
# Epoch 45
# ------------------------------
# loss: 0.441409  [   64/60000]
# loss: 0.448728  [ 6464/60000]
# loss: 0.514177  [12864/60000]
# loss: 0.503163  [19264/60000]
# loss: 0.488364  [25664/60000]
# loss: 0.670528  [32064/60000]
# loss: 0.396821  [38464/60000]
# loss: 0.409594  [44864/60000]
# loss: 0.524118  [51264/60000]
# loss: 0.323554  [57664/60000]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.505241
#
# Epoch 46
# ------------------------------
# loss: 0.454188  [   64/60000]
# loss: 0.618065  [ 6464/60000]
# loss: 0.520177  [12864/60000]
# loss: 0.319815  [19264/60000]
# loss: 0.622702  [25664/60000]
# loss: 0.561396  [32064/60000]
# loss: 0.385806  [38464/60000]
# loss: 0.594626  [44864/60000]
# loss: 0.346314  [51264/60000]
# loss: 0.585909  [57664/60000]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.503107
#
# Epoch 47
# ------------------------------
# loss: 0.519078  [   64/60000]
# loss: 0.602360  [ 6464/60000]
# loss: 0.541635  [12864/60000]
# loss: 0.413616  [19264/60000]
# loss: 0.324643  [25664/60000]
# loss: 0.544890  [32064/60000]
# loss: 0.407234  [38464/60000]
# loss: 0.652716  [44864/60000]
# loss: 0.452236  [51264/60000]
# loss: 0.546065  [57664/60000]
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.499630
#
# Epoch 48
# ------------------------------
# loss: 0.531314  [   64/60000]
# loss: 0.621927  [ 6464/60000]
# loss: 0.521517  [12864/60000]
# loss: 0.529898  [19264/60000]
# loss: 0.425623  [25664/60000]
# loss: 0.376552  [32064/60000]
# loss: 0.649692  [38464/60000]
# loss: 0.459479  [44864/60000]
# loss: 0.879613  [51264/60000]
# loss: 0.432135  [57664/60000]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.498579
#
# Epoch 49
# ------------------------------
# loss: 0.480468  [   64/60000]
# loss: 0.625092  [ 6464/60000]
# loss: 0.537883  [12864/60000]
# loss: 0.355538  [19264/60000]
# loss: 0.439459  [25664/60000]
# loss: 0.515925  [32064/60000]
# loss: 0.459032  [38464/60000]
# loss: 0.445737  [44864/60000]
# loss: 0.307939  [51264/60000]
# loss: 0.571241  [57664/60000]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.497710
#
# Epoch 50
# ------------------------------
# loss: 0.336152  [   64/60000]
# loss: 0.525127  [ 6464/60000]
# loss: 0.411148  [12864/60000]
# loss: 0.529413  [19264/60000]
# loss: 0.355492  [25664/60000]
# loss: 0.268024  [32064/60000]
# loss: 0.429720  [38464/60000]
# loss: 0.422646  [44864/60000]
# loss: 0.273487  [51264/60000]
# loss: 0.354102  [57664/60000]
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.496992
#
# Done!

# %%
plt.figure(figsize=(5,3))
plt.plot([x[0] for x in res], [x[1].item() for x in res])
plt.title(f'Test loss by epochs')
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
# 모델 가중치 저장
torch.save(model.state_dict(), 'model_weights.pth')
model_copy = MLP()
model_copy.load_state_dict(torch.load('model_weights.pth'))
model_copy.eval() # 평가모드
model_copy.state_dict()
# Out:
# <All keys matched successfully>

# %%
# 모델 저장
torch.save(model, 'model.pth')
model_copy2 = torch.load('model.pth', weights_only=False)
model_copy2.state_dict()
